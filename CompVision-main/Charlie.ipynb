# %% [markdown]
# ## Imports

# %%
# %pip install numpy matplotlib opencv-python 
#%pip install pandas seaborn sklearn scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 10/10/24
# ## Hafta 3.1
# <hr>

# %% [markdown]
# ### Plot, Cmap

# %%
resim1 = cv2.imread("./DATA/3_opencv-logo.png")
resim1 = cv2.cvtColor(resim1, cv2.COLOR_BGR2RGB)
resim2 = resim1.copy()
resim3 = resim1.copy()
resim4 = resim1.copy()

# pencere = plt.figure(figsize=(3,3))
# pencere.add_subplot(2,2,1)
# plt.imshow(resim1)
# pencere.add_subplot(2,2,2)
# plt.imshow(resim2)
# pencere.add_subplot(2,2,3)
# plt.imshow(resim3)
# pencere.add_subplot(2,2,4)
# plt.imshow(resim4)

f, eksen = plt.subplots(2,2)
eksen[0,0].imshow(resim1)
eksen[0,1].imshow(resim2)
eksen[1,0].imshow(resim3)
eksen[1,1].imshow(resim4)

# %%
##
##  Vize - 10 P
##

r = cv2.imread("DATA/1_ayasofya.jpg")

r = cv2.cvtColor(r, cv2.COLOR_BGR2RGB)
empty = np.zeros(shape= r.shape)

red = r.copy()
red[:,:,1] = 0
red[:,:,2] = 0

green = r.copy()
green[:,:,0] = 0
green[:,:,2] = 0


blue = r.copy()
blue[:,:,0] = 0
blue[:,:,1] = 0


f, eksen = plt.subplots(2,3)
f1, eksen1 = plt.subplots(2,3)
eksen[0,0].imshow(empty)
eksen[0,1].imshow(r)
eksen[0,2].imshow(empty)
eksen[1,0].imshow(red)
eksen[1,1].imshow(green)
eksen[1,2].imshow(blue)

eksen1[0,0].imshow(empty)
eksen1[0,1].imshow(r)
eksen1[0,2].imshow(empty)
eksen1[1,0].imshow(r[:,:,0], cmap='Reds')
eksen1[1,1].imshow(r[:,:,1], cmap='Greens')
eksen1[1,2].imshow(r[:,:,2], cmap='Blues')

# %% [markdown]
# ### Görüntü işleme fonksiyonları

# %%
img = cv2.imread("DATA/2_rgb.png")
plt.imshow(img)
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

cv2.threshold(img, 127, 255, )
