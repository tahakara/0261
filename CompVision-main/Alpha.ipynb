# %% [markdown]
# ## Imports

# %%
import os 
import sys
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Hafta 3
# <hr>

# %%
np.random.seed(230924)
np.random.seed(200)

# %%
a = np.random.randint(0, 100, 100).reshape(10, 10)
a
# Out:
# array([[26, 16, 68, 42, 55, 76, 79, 89, 14, 91],
#        [57, 89, 11,  6, 42, 56,  1,  7, 51, 27],
#        [73, 15,  1, 23, 85, 24,  7, 22, 54, 77],
#        [16, 70, 35, 31, 32, 45, 59, 45, 61, 20],
#        [85,  0,  3, 55, 95, 56,  3, 33, 72,  0],
#        [52, 90, 61, 70, 78, 99, 76, 58, 68, 62],
#        [52,  6, 82, 96, 27, 68, 64, 89, 68, 50],
#        [94, 97, 29, 88, 22,  7, 33, 30, 57, 97],
#        [23,  5, 40, 26, 65, 97, 81, 71, 90,  0],
#        [45, 82, 38, 37, 27, 92, 43, 46, 33, 45]], dtype=int32)

# %%
a.shape
# Out:
# (10, 10)

# %%
a[3:7, 2:5]
# Out:
# array([[35, 31, 32],
#        [ 3, 55, 95],
#        [61, 70, 78],
#        [82, 96, 27]], dtype=int32)

# %%
a[:, 0::2]
# Out:
# array([[26, 68, 55, 79, 14],
#        [57, 11, 42,  1, 51],
#        [73,  1, 85,  7, 54],
#        [16, 35, 32, 59, 61],
#        [85,  3, 95,  3, 72],
#        [52, 61, 78, 76, 68],
#        [52, 82, 27, 64, 68],
#        [94, 29, 22, 33, 57],
#        [23, 40, 65, 81, 90],
#        [45, 38, 27, 43, 33]], dtype=int32)

# %%
import cv2 # BGR
import matplotlib.pyplot as plt # RGB

# %%
r = plt.imread('DATA/1_ayasofya.jpg')

# %%
r[0, 0]
# Out:
# array([123, 166, 217], dtype=uint8)

# %%
r[500, 400] # horizontal pixel 500, vertical pixel 400
# Out:
# array([221, 212, 229], dtype=uint8)

# %%
ri = r.copy()
# all row, all column, in 1 channel (blue) set to 255 
ri[:,:,1] = 255
plt.imshow(ri)

# %%
r2 = cv2.imread('DATA/1_ayasofya.jpg')

# %%
plt .imshow(r2)

# %%
r2 = cv2.cvtColor(r2, cv2.COLOR_BGR2RGB)
plt.imshow(r2)
